# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Data Reading Tasks:

# %%
#1.Read the dataset from a CSV file into a pandas DataFrame
sales_df=pd.read_csv('sales.csv')
sales_df
# Out:
#      order_id        date region   product     category customer_type  \
# 0           1  2024-04-12   East    Laptop  Electronics     Returning
# 1           2  2024-12-14  South   Monitor  Accessories     Returning
# 2           3  2024-09-27  North     Phone  Accessories           New
# 3           4  2024-04-16   West     Mouse  Electronics     Returning
# 4           5  2024-03-12   West     Phone  Electronics     Returning
# ..        ...         ...    ...       ...          ...           ...
# 495       496  2024-11-20  South     Mouse  Accessories     Returning
# 496       497  2024-01-04  North     Phone  Accessories     Returning
# 497       498  2024-01-16  South  Keyboard  Electronics     Returning
# 498       499  2024-10-06  North     Phone  Accessories     Returning
# 499       500  2024-12-01  North   Monitor  Electronics           New
#
#      quantity  price  discount    sales
# 0           8    590      0.09  4295.20
# 1           2    262      0.18   429.68
# ...

# %%
#2.Display the first 8 rows and check the basic structure of the dataset using .info()
sales_df.head(8)
# Out:
#    order_id        date region  product     category customer_type  quantity  \
# 0         1  2024-04-12   East   Laptop  Electronics     Returning         8
# 1         2  2024-12-14  South  Monitor  Accessories     Returning         2
# 2         3  2024-09-27  North    Phone  Accessories           New         5
# 3         4  2024-04-16   West    Mouse  Electronics     Returning         1
# 4         5  2024-03-12   West    Phone  Electronics     Returning         7
# 5         6  2024-07-07   West   Laptop  Electronics           New         8
# 6         7  2024-01-21   East    Mouse  Accessories     Returning         6
# 7         8  2024-04-12   West    Phone  Accessories     Returning         5
#
#    price  discount     sales
# 0    590      0.09   4295.20
# 1    262      0.18    429.68
# 2    512      0.09   2329.60
# 3    485      0.09    441.35
# 4    332      0.22   1812.72
# 5   1480      0.01  11721.60
# 6    137      0.27    600.06
# 7   1117      0.26   4132.90

# %%
#3.Get statistical summary of numerical columns using .describe()
sales_df.describe(include='all')
# Out:
#           order_id        date region product     category customer_type  \
# count   500.000000         500    500     500          500           500
# unique         NaN         267      4       6            2             2
# top            NaN  2024-04-08  North   Mouse  Electronics     Returning
# freq           NaN           6    151      96          266           261
# mean    250.500000         NaN    NaN     NaN          NaN           NaN
# std     144.481833         NaN    NaN     NaN          NaN           NaN
# min       1.000000         NaN    NaN     NaN          NaN           NaN
# 25%     125.750000         NaN    NaN     NaN          NaN           NaN
# 50%     250.500000         NaN    NaN     NaN          NaN           NaN
# 75%     375.250000         NaN    NaN     NaN          NaN           NaN
# max     500.000000         NaN    NaN     NaN          NaN           NaN
#
#           quantity        price   discount         sales
# ...

# %%
#4.Check column names and rename any columns for better readability (e.g., rename 'order_id' to 'OrderID')
sales_df.rename(columns={'price': 'Amount'}, inplace=True)
sales_df
# Out:
#      order_id        date region   product     category customer_type  \
# 0           1  2024-04-12   East    Laptop  Electronics     Returning
# 1           2  2024-12-14  South   Monitor  Accessories     Returning
# 2           3  2024-09-27  North     Phone  Accessories           New
# 3           4  2024-04-16   West     Mouse  Electronics     Returning
# 4           5  2024-03-12   West     Phone  Electronics     Returning
# ..        ...         ...    ...       ...          ...           ...
# 495       496  2024-11-20  South     Mouse  Accessories     Returning
# 496       497  2024-01-04  North     Phone  Accessories     Returning
# 497       498  2024-01-16  South  Keyboard  Electronics     Returning
# 498       499  2024-10-06  North     Phone  Accessories     Returning
# 499       500  2024-12-01  North   Monitor  Electronics           New
#
#      quantity  Amount  discount    sales
# 0           8     590      0.09  4295.20
# 1           2     262      0.18   429.68
# ...

# %% [markdown]
# Data Cleaning Tasks:

# %%
#5.Check for missing values in each column and handle them appropriately
print(sales_df.isnull().sum())
# Out:
# order_id         0
# date             0
# region           0
# product          0
# category         0
# customer_type    0
# quantity         0
# Amount           0
# discount         0
# sales            0
# dtype: int64

# %%
#6.Check for duplicate rows and remove any duplicates if found
sales_count = sales_df.duplicated().sum()
sales_df.drop_duplicates(inplace=True)
print(sales_df.shape)
# Out:
# (500, 10)

# %%
#7.Convert 'date' column to datetime format
sales_df.rename(columns={'date': 'Datetime'}, inplace=True)
sales_df
# Out:
#      order_id    Datetime region   product     category customer_type  \
# 0           1  2024-04-12   East    Laptop  Electronics     Returning
# 1           2  2024-12-14  South   Monitor  Accessories     Returning
# 2           3  2024-09-27  North     Phone  Accessories           New
# 3           4  2024-04-16   West     Mouse  Electronics     Returning
# 4           5  2024-03-12   West     Phone  Electronics     Returning
# ..        ...         ...    ...       ...          ...           ...
# 495       496  2024-11-20  South     Mouse  Accessories     Returning
# 496       497  2024-01-04  North     Phone  Accessories     Returning
# 497       498  2024-01-16  South  Keyboard  Electronics     Returning
# 498       499  2024-10-06  North     Phone  Accessories     Returning
# 499       500  2024-12-01  North   Monitor  Electronics           New
#
#      quantity  Amount  discount    sales
# 0           8     590      0.09  4295.20
# 1           2     262      0.18   429.68
# ...

# %%
#8.Check data types of all columns and convert if necessary (e.g., ensure 'quantity' is int, 'price' is float)
print(sales_df.dtypes)
# Out:
# order_id           int64
# Datetime             str
# region               str
# product              str
# category             str
# customer_type        str
# quantity           int64
# Amount             int64
# discount         float64
# sales            float64
# dtype: object

# %%
#9.Standardize 'region' values (ensure consistent capitalization and remove extra spaces)
sales_df['region'] = sales_df['region'].str.title()
sales_df
# Out:
#      order_id    Datetime region   product     category customer_type  \
# 0           1  2024-04-12   East    Laptop  Electronics     Returning
# 1           2  2024-12-14  South   Monitor  Accessories     Returning
# 2           3  2024-09-27  North     Phone  Accessories           New
# 3           4  2024-04-16   West     Mouse  Electronics     Returning
# 4           5  2024-03-12   West     Phone  Electronics     Returning
# ..        ...         ...    ...       ...          ...           ...
# 495       496  2024-11-20  South     Mouse  Accessories     Returning
# 496       497  2024-01-04  North     Phone  Accessories     Returning
# 497       498  2024-01-16  South  Keyboard  Electronics     Returning
# 498       499  2024-10-06  North     Phone  Accessories     Returning
# 499       500  2024-12-01  North   Monitor  Electronics           New
#
#      quantity  Amount  discount    sales
# 0           8     590      0.09  4295.20
# 1           2     262      0.18   429.68
# ...

# %%
sales_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       500 non-null    int64
#  1   Datetime       500 non-null    str
#  2   region         500 non-null    str
#  3   product        500 non-null    str
#  4   category       500 non-null    str
#  5   customer_type  500 non-null    str
#  6   quantity       500 non-null    int64
#  7   Amount         500 non-null    int64
#  8   discount       500 non-null    float64
#  9   sales          500 non-null    float64
# dtypes: float64(2), int64(3), str(5)
# memory usage: 39.2 KB

# %%
#11.Calculate total sales by region and find which region has the highest sales

total_sales = sales_df.groupby("region")["sales"].sum().idxmax()
total_sales
# Out:
# 'North'

# %%
#12.Find the average discount given for each product category

# %%
#13.Analyze customer ratings - calculate average rating by customer type (New vs Returning)ratings = sales_df.groupby('customer_type')('sales').agg("mean")

# %%
#13.Find top 5 products by quantity sold
top_5_products = sales_df.groupby('Product')['Quantity'].sum().agg('largest(5)')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[107], line 2
#       1 #13.Find top 5 products by quantity sold
# ----> 2 top_5_products = sales_df.groupby('Product')['Quantity'].sum().agg('largest(5)')
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:10817, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
# ...
