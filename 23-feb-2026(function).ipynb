# %%
x=6


while x > 0:
    print(x)
    x -= 1

print("Blastoff!")
# Out:
# 6
# 5
# 4
# 3
# 2
# 1
# Blastoff!

# %%
age = 34
print( 'adult' if age >=18 else 'Children')
# Out:
# adult

# %%
man = (x*x for x in range(10))
print(man)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 man = (x*x for x in range(10))
# ----> 2 print(list(man))
#
# TypeError: 'generator' object is not callable

# %%
def greet():
          return("hello world!")

greet()
# Out:
# 'hello world!'

# %%
def greet(age, name):
          return f"hello, {name}! You are {age} year old."

greet(20, 'alice')
# Out:
# 'hello, alice! You are 20 year old.'

# %%
def welcome(name='uer'):
    return f"Welcome, {name}!"

welcome('ali baba')
# Out:
# 'Welcome, ali baba!'

# %%
def show(**Numbers):
    return f"Numbers: {numbers}!"

show (1,2,'ali',3,4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 def show(*Numbers):
#       2     return f"Numbers:  {numbers}!"
# ----> 4 show(1,2,'ali',3,4)
#
# Cell In[15], line 2, in show(*Numbers)
#       1 def show(*Numbers):
# ----> 2     return f"Numbers:  {numbers}!"
#
# NameError: name 'numbers' is not defined

# %%
y=10

def scope_test():
    x=5
    print(x+y)
    scope_test(x)
    print(x)

# %%
y=10

def scope_test():
    x=5
    print(x+y)
    scope_test(x)
    print(x)
