# %% [markdown]
# ## Day 3
# **Values, Expressions, Statements**

# %%
# 1. Print any integer number
x=4
print(x)
# Out:
# 4

# %%
# 2. Print a floating‑point number
x=5.5
print(x)
# Out:
# 5.5

# %%
# 3. Print a Boolean value
print('true')
# Out:
# true

# %%
# 4. Store your age in a variable and print it
age=x
x=21
print('age:')
print(x)
# Out:
# age:
# 21

# %%
# 5. Add two numbers and print result
x = 5
y = 10
sum_result = x + y
print(sum_result)
# Out:
# 15

# %%
# 6. Multiply two numbers
x=8
y=6
multiply_result=x*y
print(multiply_result)
# Out:
# 48

# %%
# 7. Compare two numbers using > operator
x=10
if x > 5:
     print('x is greater than 5')
else:
     print('x is not greater than 5')
# Out:
# x is greater than 5

# %%
# 8. Create a string variable with your name
name = "Rimsha Nermeen"
print(name)
# Out:
# Rimsha Nermeen

# %%
# 9. Print sum of 3 + 7 * 2
x=3
y=7
z=2
sum_result=x+y
print(sum_result*z)
# Out:
# 20

# %%
# 10. Check if 10 equals 10
x=10
if x > 10:
    print('x is greater than 10')
elif x == 10:
    print('x is equal to 10')
else:
    print('x is not equal to  10')
# Out:
# x is equal to 10

# %% [markdown]
# ## Day 3
# **String Operations**

# %%
# 1. Create a string "Python"
x="python"
print(x)
# Out:
# python

# %%
# 2. Concatenate your name with " Khan"
name= 'Rimsha'
full_name=name+' Nermeen'
print(full_name)
# Out:
# Rimsha Nermeen

# %%
# 3. Repeat a string 3 times
name ="Rimsha"
result = name*3

# %%
# 4. Print first character of a string
txt = 'beautiful'
print(txt[0])
# Out:
# b

# %%
# 5. Slice first 4 characters
txt = 'beautiful'
print(txt[0:3])
# Out:
# bea

# %%
# 6. Find length of string
txt= ('this is my Book')
print(len(txt))
# Out:
# 15

# %%
# 7. Convert string to lowercase
txt= ('This is my Book')
print (txt.lower())
# Out:
# this is my book

# %%
# 8. Convert string to uppercase
txt= ('This is my Book')
print(txt.upper())
# Out:
# THIS IS MY BOOK

# %%
# 9. Replace one word with another
txt= ('This is my Book')
new_txt= txt.replace("This", "That")
print(new_txt)
# Out:
# That is my Book

# %%
# 10. Check if substring exists
txt= " I love Pakistan "
if "Pakitan" in txt:
    print (" Pakistan exixt ")
else:
    print("Pakistan doesn't exist")
# Out:
# Pakistan doesn't exist

# %% [markdown]
# ## Day 3
# **Input, Type Casting, Comments**

# %%
# 1. Take name input from user
name = input("Enter Your Name: ")
print(" Hello ", name)
# Out:
# Hello  Rimsha Nermeen

# %%
# 2. Take age input and convert to int
age = int(input('Enter Your Age:'))
print(age)
# Out:
# 21

# %%
# 3. Take decimal input and convert to float
x = float(input("Enter a decimal number: "))
print('Your number is: ', x)
# Out:
# Your number is:  5.57

# %%
# 4. Convert string "100" to integer
num_str=100
num_int=int(num_str)
print(num_str)
print(num_int)
# Out:
# 100
# 100

# %%
# 5. Convert number 50 to string
number=50
num_str = str(number)
print(num_str)
# Out:
# 50

# %%
# 6. Write a single‑line comment

#num_str = str(number)

# %%
# 7. Add two input numbers
num1=int(input("Enter Number 1: "))
num2= int(input("Enter Number 2: "))
sum = (num1+num2)
print("The sum is: ", sum)
# Out:
# The sum is:  121

# %%
# 8. Convert 0 to Boolean
print(bool(0))
# Out:
# False

# %%
# 9. Convert 1 to Boolean
print(bool(1))
# Out:
# True

# %%
# 10. Print greeting using input name
name = input("Enter your Name: ")
print ("Hello: ", name)
# Out:
# Hello:  Rimsha Nermeen
